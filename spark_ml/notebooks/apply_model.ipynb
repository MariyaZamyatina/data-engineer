// %%
import org.apache.spark.sql.types.{StructType, StringType}
import org.apache.spark.ml.{Pipeline, PipelineModel}
import org.apache.spark.sql.functions._
import org.apache.spark.sql.DataFrame
import org.apache.spark.streaming._

// %%
println(s"Current spark version is ${spark.version}")
// Out:
// Current spark version is 2.4.4

// %%
val inputStreamPath = "/home/jovyan/data/events-stream"

val dataSchema = new StructType()
    .add("tweet", StringType)

val inputDF = spark
    .readStream
    .schema(dataSchema)
    .option("maxFilesPerTrigger", 1)
    .json(inputStreamPath)
// Out:
// inputStreamPath = /home/jovyan/data/events-stream
// dataSchema = StructType(StructField(tweet,StringType,true))
// inputDF = [tweet: string]
// [tweet: string]

// %%
val modelPath = "/home/jovyan/models/spark-ml-model"

val model = PipelineModel.load(modelPath)
// Out:
// modelPath = /home/jovyan/models/spark-ml-model
// model = pipeline_9dba2f215e93
// pipeline_9dba2f215e93

// %%
val getNegativeProbability = 
    udf((prediction: org.apache.spark.ml.linalg.Vector) => prediction(1))
// Out:
// getNegativeProbability = UserDefinedFunction(<function1>,DoubleType,Some(List(org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7)))
// UserDefinedFunction(<function1>,DoubleType,Some(List(org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7)))

// %%
val predictionsDF = model
    .transform(inputDF)
    .withColumn("neg_probability", getNegativeProbability($"probability"))
    .select($"tweet", $"prediction", $"neg_probability")
// Out:
// predictionsDF = [tweet: string, prediction: double ... 1 more field]
// [tweet: string, prediction: double ... 1 more field]

// %%
val predictions_stream = predictionsDF.writeStream.foreachBatch {
    (batchDF: DataFrame, batchId: Long) => batchDF.show()
}.start()
// Out:
// predictions_stream = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@6829cc79
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@6829cc79
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@Spitphyre ohhhh ...|       1.0| 0.5229983027094914|
// |aww no pubefros? ...|       0.0|0.42704340603968527|
// |does NOT want to ...|       0.0| 0.4951221335857083|
// |have to go to wor...|       0.0|0.48464601632498255|
// |is going to be - ...|       0.0| 0.4471516640537588|
// |@barbiesdead i wa...|       0.0| 0.4763973438000497|
// |@DanielKGlenn Ok ...|       0.0|0.36091964624114514|
// |@Zzazz  my weeken...|       0.0|0.49735163144942296|
// |I'm up, but I wen...|       0.0|0.46006371760813325|
// |@jenswitzig &quot...|       0.0| 0.4702047324259545|
// |watching funny mo...|       1.0| 0.5377644764806815|
// |@betaboy Arrrrrgh...|       1.0| 0.5259401762003582|
// |@Ilkee yeah, too ...|       0.0| 0.4900060643943062|
// |Oh i love that mo...|       0.0| 0.4846421793506976|
// |@rainbowbtrfly If...|       1.0| 0.5356092962905977|
// |hmmmmm. really li...|       0.0| 0.4757844194249655|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@nick_carter you ...|       1.0| 0.5387450342438135|
// |@imeantheend lol ...|       1.0| 0.5217622596942644|
// |@Claire_inLaPush ...|       1.0| 0.5076152473383724|
// |i really want to ...|       0.0|0.41324061782429833|
// |i just want to st...|       0.0|0.46543972018039464|
// |y must yellow eye...|       0.0|0.49487387218565926|
// |@napalm84 no I'm ...|       0.0| 0.4471516640537588|
// |Dear God, please ...|       0.0| 0.4962577627950444|
// |9th november glas...|       0.0| 0.4730304328806357|
// |I miss FC.  I wan...|       0.0| 0.4488923079260824|
// |I also have Theo ...|       0.0| 0.4731973768014129|
// |what's your perfe...|       1.0| 0.5346279686983664|
// |@NathanFillion aw...|       1.0| 0.5217622596942644|
// |@BOGEY117 Yeah it...|       1.0| 0.5157563715281381|
// |took M1n2 to movi...|       1.0| 0.5054286335023478|
// |time to mega clea...|       1.0| 0.5134531950981953|
// |@jasonsechrest LO...|       0.0|0.46325977002389684|
// |I think that's en...|       0.0|0.48924897025962377|
// |@jedi58 indeed it...|       0.0|0.46564256893394473|
// |Ahhhh tired doooo...|       1.0| 0.5134531950981953|
// +--------------------+----------+-------------------+
// only showing top 20 rows
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |       I'm cold now |       1.0| 0.5134531950981953|
// |the tops of my le...|       0.0|0.48099506217818133|
// |Bored, wish someo...|       1.0| 0.5157563715281381|
// |@jaxelle I hope s...|       0.0| 0.4297787881536547|
// |you it really sux...|       1.0| 0.5078539675689445|
// |     I'm very bored |       0.0|0.47892653615085107|
// |@mikhailgm That's...|       1.0|  0.542939675217404|
// |@suzieharris_8  o...|       1.0| 0.5253961141044412|
// |off to shul for S...|       1.0| 0.5134531950981953|
// |I have a new favo...|       0.0| 0.4624406479148675|
// |Photo is fixed! M...|       1.0| 0.5217622596942644|
// |@ urbsoph great i...|       0.0| 0.4557560710329187|
// |Youngest Daughter...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |took you a while ...|       0.0| 0.4442785346631303|
// |such a nice day a...|       0.0|0.47082818929294623|
// |i wanna see taylo...|       0.0| 0.4511225894937588|
// |@froppishpet no t...|       0.0| 0.4385313428062408|
// |@xLoveLovexAblex ...|       0.0|0.45512245350842406|
// |@adelablue You wi...|       1.0| 0.5346138861538383|
// |@MissFarrah hey  ...|       1.0| 0.5259401762003582|
// |@Armano I bet the...|       0.0| 0.4920798462889506|
// |New moon trailer ...|       1.0| 0.5217622596942644|
// |i'm going to enjo...|       1.0| 0.5388580736243476|
// |@patty_la aaaaaaa...|       1.0| 0.5217622596942644|
// |getting warm &amp...|       1.0| 0.5000718244764134|
// |Take Me On The Fl...|       0.0| 0.4837707816928815|
// |@love4art2j Cute,...|       0.0| 0.4920798462889506|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |Happy Saturday Tw...|       1.0| 0.5080827960066919|
// |@PerfectTenEnt ye...|       1.0| 0.5217622596942644|
// |@earthkid26 They ...|       0.0|0.47243398365857886|
// |@thisisamirra im ...|       0.0| 0.4918020460487882|
// |Last night I was ...|       0.0|  0.493368846728827|
// |@mitchelmusso i d...|       0.0| 0.4835756118027887|
// |About to watch th...|       1.0| 0.5000547859568538|
// |@Shaniceonline pl...|       1.0| 0.5134531950981953|
// |Bad morning! I'm ...|       1.0| 0.5083166218007302|
// |Well I'm off 2 be...|       0.0|0.48301466655904246|
// |@DreamWorthy I'm ...|       1.0| 0.5134531950981953|
// |Making ice cream....|       1.0| 0.5311504032472203|
// |in college bored ...|       0.0|0.48723560074692013|
// |@MissDadeCounty  ...|       1.0| 0.5157563715281381|
// |im soooo sleepy!!...|       0.0| 0.4837707816928815|
// |Yeah yeah yeahs o...|       1.0| 0.5023115391239122|
// |eating a banana a...|       1.0| 0.5388058852044602|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |rain finally stop...|       1.0| 0.5134531950981953|
// |at work 11 hours ...|       1.0| 0.5055470570681241|
// |@Joanne84 you do ...|       1.0| 0.5387450342438135|
// |@mspixieriot aww,...|       0.0|0.47776489352675533|
// |@MusicalD Why do ...|       0.0| 0.4780915870569048|
// |has like no follo...|       0.0| 0.4508717667906398|
// |Tired. So very ti...|       1.0| 0.5143245927560114|
// |@ShaniBeeGirl aha...|       1.0| 0.5217622596942644|
// |fingers crossed i...|       0.0| 0.4797476381178886|
// |supposed to be ta...|       0.0|0.47226619571007467|
// |http://twitpic.co...|       0.0| 0.4920798462889506|
// |Last Night: 2 Win...|       1.0| 0.5042327024629477|
// |@souljaboytellem ...|       1.0| 0.5217622596942644|
// |@raideraid  Tomor...|       0.0|0.47876030366351474|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |I just slammed my...|       0.0| 0.4689769843372926|
// |Only a few more h...|       1.0|  0.504433754394614|
// |Chicago lost  tha...|       1.0| 0.5217622596942644|
// |Urrrgh..i wish i ...|       0.0|0.46188722114776154|
// |Doing my homework...|       0.0| 0.4837707816928815|
// |My freakin ubertw...|       1.0| 0.5217622596942644|
// |Damn the Rainy Da...|       1.0| 0.5057551171421122|
// |@SuzeMuse uhm... ...|       1.0| 0.5217622596942644|
// |The taste of medi...|       1.0| 0.5134531950981953|
// |Hanging my head i...|       1.0| 0.5217622596942644|
// |don't feel well. ...|       0.0| 0.4937475490343014|
// |@SoozieQ I am NOT...|       0.0|0.47080495599732497|
// |wow i just spent ...|       0.0|0.47792670128255754|
// |      at home again |       1.0| 0.5217622596942644|
// |@LeEyeCandy Ohh, ...|       1.0| 0.5217622596942644|
// |@AbbieFletcher_ y...|       1.0| 0.5387450342438135|
// |@YoungQ Cool cool...|       0.0| 0.4962577627950444|
// |@19fischi75 hav a...|       1.0| 0.5259401762003582|
// |@candlelight It's...|       0.0| 0.4837707816928815|
// |Thinks mayb Feder...|       1.0| 0.5043608294113009|
// +--------------------+----------+-------------------+
// only showing top 20 rows
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |I want people to ...|       0.0|0.46543972018039464|
// |@danabaker Thanks...|       1.0| 0.5137376980984167|
// |@_nicoke  that su...|       1.0| 0.5090626208384997|
// |       @crazygood53 |       1.0| 0.5217622596942644|
// |ha damn......my h...|       0.0| 0.4227038653335133|
// |I want a new job ...|       0.0| 0.4897510015628808|
// | @SalaamFreeland no |       0.0|0.46157006498702946|
// |@adammshankman AM...|       0.0| 0.4688111982154906|
// |@CherylRCorbin Se...|       0.0| 0.4918846763988577|
// |@dinibeanie yeah ...|       1.0| 0.5026583791423492|
// |@mongab I was in ...|       1.0| 0.5017489663791901|
// |@mandiebear Thank...|       1.0| 0.5217622596942644|
// |@Mr_Metal Can't w...|       1.0| 0.5134531950981953|
// |Why most famous p...|       1.0| 0.5289514159853582|
// |Just woke up at t...|       0.0| 0.4926362021009843|
// |well off to bed  ...|       1.0| 0.5134531950981953|
// +--------------------+----------+-------------------+
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |ok, considering i...|       0.0|0.48074564695038413|
// |my procrastinatio...|       0.0| 0.4730724834964919|
// |My sunburn huuuuu...|       1.0| 0.5217622596942644|
// |Missed the bus......|       1.0| 0.5217622596942644|
// |At work. Unfortun...|       0.0| 0.4837707816928815|
// |blimey it is prop...|       0.0| 0.4496439525208043|
// |@BronteFan2 What ...|       1.0| 0.5387450342438135|
// |@rvailleux : woot...|       0.0| 0.4898415707664526|
// |@officialTila Hea...|       1.0| 0.5217622596942644|
// |is watching GG.. ...|       1.0| 0.5217622596942644|
// |is thinking &quot...|       1.0| 0.5217622596942644|
// |Taking a break fr...|       1.0| 0.5176311116042892|
// |is waiting for @a...|       0.0| 0.4987018737006327|
// |Just got the new ...|       1.0| 0.5217622596942644|
// |@ash_786 I like y...|       0.0| 0.4920798462889506|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@LiverpoolMich fu...|       0.0|0.47685165558638287|
// |seen yest. today ...|       0.0| 0.4977706926092944|
// |@DavidHender not ...|       0.0|0.47893571716629724|
// |Never thought I'd...|       0.0| 0.4497572176914937|
// |@just_jess_jess P...|       0.0| 0.4567138584946845|
// |@Vinkersole Yep.....|       1.0| 0.5259401762003582|
// |Thx everyone for ...|       1.0| 0.5217622596942644|
// |Feeling high as a...|       1.0| 0.5019486091153883|
// |@BReal_2 : MAN an...|       0.0|0.45906936692935557|
// |@LeighanneReena m...|       1.0| 0.5217622596942644|
// |@torgo &quot;open...|       1.0| 0.5062557536357236|
// |Another Bloody Bo...|       1.0| 0.5217622596942644|
// |wow, SAT's made t...|       0.0|0.49754676323492086|
// |@Claire_Cordon Tr...|       1.0| 0.5134531950981953|
// |Whoop whoop! Am b...|       0.0|0.47525453372375015|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |    not in the mood |       1.0| 0.5004873694026386|
// |Back to work for ...|       1.0| 0.5176311116042892|
// |I know why I usua...|       0.0| 0.4741109998269379|
// |this is it. I'll ...|       1.0| 0.5217622596942644|
// |Okay, it's June 1...|       1.0| 0.5004873694026386|
// |In the summer. I ...|       0.0| 0.4837707816928815|
// |Aww my trackball ...|       1.0| 0.5217622596942644|
// |on my way home. P...|       1.0| 0.5039885831223445|
// |@EmoLaurie LOL!!!...|       1.0| 0.5060797572053635|
// |i had a dream las...|       0.0|0.49754676323492086|
// |errbody, please c...|       1.0| 0.5199342880342319|
// |I keep stepping o...|       0.0|0.47226619571007467|
// |@onm_uk oh my goo...|       1.0| 0.5043608294113009|
// |@DaveJMatthews La...|       1.0| 0.5388344772752658|
// |I love buffets it...|       0.0| 0.4962577627950444|
// |@jfriend I need v...|       0.0| 0.4678931093138877|
// |I dont know how u...|       0.0|0.47603141065205434|
// |uploading while O...|       1.0| 0.5217622596942644|
// |@myotherhand ah! ...|       1.0| 0.5217622596942644|
// |@minorissues har ...|       1.0| 0.5074473069320691|
// +--------------------+----------+-------------------+
// only showing top 20 rows
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@reallysketchyyy ...|       0.0|0.48474641369027854|
// |Yeah, I gotta wor...|       0.0| 0.4473310696402919|
// |I think I'm gonna...|       0.0| 0.4720735667620971|
// |i feel unbelievab...|       0.0|0.40162598786995474|
// |says i miss you s...|       0.0|0.47051851409851214|
// |uhhhhrr work &amp...|       1.0| 0.5217622596942644|
// |As of Friday ever...|       0.0|0.46543972018039464|
// |Beautiful ...mugg...|       0.0| 0.4681104916525256|
// |WTF. I went to wo...|       0.0|0.47574622009703404|
// |Ah, nice, one les...|       1.0| 0.5134531950981953|
// |@Bia_Loves_NKOTB ...|       0.0|0.47657334023040987|
// |Fuck you @chelsea...|       1.0| 0.5118448539459666|
// |@supersandro ever...|       0.0| 0.4860739581228244|
// |@thecomagirl me t...|       0.0| 0.4326129606578763|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |Ugh. Back to 40 d...|       1.0| 0.5134531950981953|
// |good night twigga...|       1.0| 0.5132572618120903|
// |@colleenwild. I t...|       0.0| 0.4859424514113459|
// |Just made myself ...|       0.0|0.43076929606881703|
// |@eviljeanius It's...|       0.0| 0.4920798462889506|
// |@andrea_r There a...|       0.0| 0.4702437749405096|
// |still cant get ov...|       0.0| 0.4847661918296409|
// |&lt;-- Winchester...|       0.0| 0.4977706926092944|
// |@jaleesaa Oh, I d...|       0.0| 0.4797476381178886|
// | @Dmizzle12 me too. |       1.0| 0.5217622596942644|
// |laying down on my...|       0.0|0.47781158492112885|
// |I have to go to t...|       0.0| 0.4714385735218195|
// |i miss christina ...|       0.0|  0.453535739548963|
// |@Ashuchan DEEP FR...|       1.0| 0.5217622596942644|
// |@PoisonIvy69 Yeah...|       1.0|  0.534630610621335|
// |@wendywings how a...|       1.0| 0.5217622596942644|
// |@Jonasbrothers  y...|       1.0| 0.5346138861538383|
// |@mjnypost good lu...|       1.0|  0.534630610621335|
// |decidedi just mig...|       1.0| 0.5004234888062287|
// |@attheboutique1 I...|       1.0| 0.5090626208384997|
// +--------------------+----------+-------------------+
// only showing top 20 rows
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |  Feeling abandoned |       1.0| 0.5217622596942644|
// |@Ghostflowerr I h...|       0.0| 0.4962577627950444|
// |@darrellbutcher *...|       1.0| 0.5046652859087326|
// |I woke up so late...|       0.0|0.47633311475462864|
// |@ted_power That w...|       0.0|0.46628160812118324|
// |@iwokemyselfup ha...|       0.0| 0.4601825044648454|
// |@nadie20 THE MAID...|       1.0| 0.5122616418018497|
// |@FRANKIEBABY09 LO...|       0.0| 0.4920798462889506|
// |@KKErwin haha yay...|       0.0|0.42444998464346273|
// |I think i ate my ...|       0.0| 0.4920798462889506|
// |@Autumn4given jus...|       1.0| 0.5134531950981953|
// |@AstroHealer than...|       1.0| 0.5212502009506452|
// |@nytimeskristof @...|       1.0| 0.5176311116042892|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |Ah really bad tum...|       0.0| 0.4928109212314977|
// |   At work so tired |       1.0| 0.5143245927560114|
// |Trying to comfort...|       0.0|0.45627234841172637|
// |@ddeeaannnnaa89 a...|       1.0|  0.503904146569274|
// |Just got finished...|       1.0| 0.5259401762003582|
// |Cancelling holidays |       1.0| 0.5217622596942644|
// |@J0Vl I didn't ge...|       0.0| 0.4764571272335719|
// |Probabley gonna f...|       0.0|0.40425594967973877|
// |why are people so...|       1.0| 0.5039885831223445|
// |UGH TBS IS IN PA ...|       1.0| 0.5134531950981953|
// |@sotak you're hav...|       1.0| 0.5217622596942644|
// |@lil_meg_91 I kno...|       0.0| 0.4054310057987348|
// |http://twitpic.co...|       1.0| 0.5217622596942644|
// |@uHear_mE_ROAR ho...|       1.0| 0.5217622596942644|
// |@gwynduffy wellll...|       0.0|0.46295378869567055|
// |@mandaamorello Se...|       1.0| 0.5387450342438135|
// |Back to the grind...|       1.0| 0.5134531950981953|
// |@DENISE_RICHARDS ...|       0.0| 0.4906306025308574|
// |People that eat n...|       1.0| 0.5597623043383348|
// |dont go tom, stay...|       1.0| 0.5134531950981953|
// +--------------------+----------+-------------------+
// only showing top 20 rows
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |is sad it's raini...|       0.0| 0.4287097534996396|
// |monkeys!!! oh man...|       0.0| 0.4464517985577179|
// |@euphorialuv Twit...|       1.0| 0.5387450342438135|
// |            Fuck .. |       1.0| 0.5217622596942644|
// |We're being total...|       0.0|0.46097340648721596|
// |Man Utd in new sh...|       1.0| 0.5217622596942644|
// |Bored,tired,cripp...|       1.0| 0.5217622596942644|
// |In the Munich Air...|       1.0| 0.5134531950981953|
// |  About to go home, |       1.0| 0.5134531950981953|
// |@sherianelfie I t...|       0.0| 0.4466584537250207|
// |@scarequotes No, ...|       0.0| 0.4396728317280165|
// |caught a nice loo...|       1.0| 0.5259401762003582|
// |@Melissa_Ungco I ...|       1.0| 0.5132405373445936|
// |@Edy7 PLEASE CHEC...|       0.0| 0.4851010776636862|
// |Just cut open my ...|       1.0| 0.5219527429020391|
// |Called a buddy an...|       1.0| 0.5055834064334486|
// +--------------------+----------+-------------------+
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@drtiet I am in s...|       0.0| 0.4962577627950444|
// |        @whitespats |       1.0| 0.5217622596942644|
// |Mafia Wars is exp...|       0.0| 0.4547069085821989|
// |I really do not k...|       0.0| 0.4668140696203028|
// | leaving home again |       1.0| 0.5217622596942644|
// |watching SP1 inst...|       1.0| 0.5217622596942644|
// |It's soooo hot. I...|       0.0| 0.4797476381178886|
// |Wohoo! Going to s...|       1.0| 0.5060155281599423|
// |happy mothers day...|       1.0|  0.511342546438851|
// |@DcTannerHo i lov...|       0.0|0.46097340648721596|
// |Wanna follow more...|       1.0| 0.5000718244764134|
// |lovin my time in ...|       1.0| 0.5217622596942644|
// |Study..study..stu...|       1.0| 0.5346279686983664|
// |Thought I'd mix u...|       1.0| 0.5176311116042892|
// |@ZnaTrainer My pl...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@moebiuscascade  ...|       1.0| 0.5599224497669532|
// |@TheMeganJo how a...|       0.0| 0.4667389175555254|
// |@mileycyrus I kno...|       0.0| 0.4672578828403754|
// |btw naked &amp; a...|       0.0|0.43884134229694993|
// |@ExtraordMommy my...|       1.0| 0.5217622596942644|
// |Mvd boo  I could ...|       0.0| 0.4835756118027887|
// |@Zainkeebab I fou...|       0.0| 0.4920798462889506|
// |@opinionatedant I...|       1.0| 0.5217622596942644|
// |aaaahh! i woke up...|       0.0| 0.4920798462889506|
// |Boring day. Regre...|       0.0| 0.4819428100328492|
// |Ha ha! Just notic...|       0.0|  0.493368846728827|
// |@megannmaccx33 th...|       0.0|0.49303052534328123|
// |seeing the hangov...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@Isak I've had th...|       0.0|0.47203979393647477|
// |@BiGVixXen Like d...|       0.0|0.45847274782626296|
// | Not feeling great. |       1.0| 0.5004873694026386|
// |@Lopsi  poor wee ...|       1.0| 0.5217622596942644|
// |on the way back f...|       1.0| 0.5217622596942644|
// |@fearfuldogs yeah...|       0.0|0.46406513562898766|
// |@MarcHaduch when ...|       1.0| 0.5125417670590167|
// |     I hate storms. |       0.0|0.47378216059086187|
// |@DavidArchie  Dav...|       0.0|0.49930618274230343|
// |@sublicon I can p...|       0.0|0.47656773044429024|
// |Essay at almost 3...|       1.0| 0.5143245927560114|
// |@dreamboatann Sea...|       1.0| 0.5217622596942644|
// |@kfcarrie OH LOL ...|       0.0| 0.4763973438000497|
// |@BUTCH_LEAKE Morn...|       1.0| 0.5217622596942644|
// |spent the early a...|       0.0|0.45697817351889486|
// |Is rolling around...|       1.0| 0.5134531950981953|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@miracleboy1973 a...|       1.0| 0.5199342880342319|
// |I want a rhd eg h...|       0.0|0.47792670128255754|
// |Its so quiet arou...|       1.0| 0.5143245927560114|
// |I deeply condole ...|       0.0|0.47574622009703404|
// |Pissed off at my ...|       1.0| 0.5217622596942644|
// |my chocolate milk...|       1.0| 0.5217622596942644|
// |Kiddo yakked 8 ti...|       1.0| 0.5217622596942644|
// |@lilithhecate BUT...|       1.0| 0.5060797572053635|
// |@TheMacMommy I wa...|       0.0|0.48615794532711626|
// |@maestroknows @li...|       0.0| 0.4920798462889506|
// |@postsecret Thank...|       1.0| 0.5299239109041254|
// |@TobyWanKenoby LO...|       0.0| 0.4920798462889506|
// |@mattHoneywill en...|       1.0| 0.5217622596942644|
// |is now in east co...|       1.0| 0.5017923460912959|
// |Walking the mall ...|       0.0| 0.4745132452867537|
// |@Calindria Comple...|       1.0| 0.5199342880342319|
// |Doesn't have a ph...|       0.0| 0.4424396864113257|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@mileycyrus so i ...|       0.0|0.48261759110778807|
// |The End of the Li...|       0.0|0.49649648302561655|
// |@tweegygibson Umm...|       0.0| 0.4557560710329187|
// |Sigh... I have to...|       0.0|0.47656773044429024|
// |This is the shitt...|       1.0| 0.5217622596942644|
// |Holy crap! Poor g...|       0.0| 0.4340083170334931|
// |@l0v3bomb Is that...|       1.0| 0.5039885831223445|
// |@missgreens ooo 2...|       0.0| 0.4725498091687922|
// |Going to watch my...|       1.0| 0.5101934446660362|
// |shit you mister g...|       1.0| 0.5387450342438135|
// |@GetaGetawayGirl ...|       1.0| 0.5231223151884349|
// |@lovetoiceskate D...|       0.0|0.48794869819897546|
// |       @leonathorst |       1.0| 0.5217622596942644|
// |@samantharonson y...|       1.0| 0.5259401762003582|
// |i love chocolate ...|       0.0| 0.4920798462889506|
// |making scones wit...|       1.0| 0.5217622596942644|
// |@darrenmurphy Ahh...|       0.0| 0.4904570381499848|
// |@SK8TERIZHAPPY ye...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+------------------+
// |               tweet|prediction|   neg_probability|
// +--------------------+----------+------------------+
// |@xsandhearts I'm ...|       0.0|0.4837707816928815|
// |@LoBosworth I agree |       0.0|0.4920798462889506|
// |im awake with a k...|       0.0|0.4911069658298125|
// |trying to figure ...|       0.0|0.4835756118027887|
// |@beckiechangg I a...|       0.0|0.4902518746289182|
// |Today I saw some ...|       0.0|0.4846421793506976|
// |snow in April...j...|       1.0|0.5217622596942644|
// |just made a twitt...|       0.0|0.4948337363986236|
// |appreciate late n...|       0.0|0.4680882792039807|
// |Celebratory brunc...|       1.0|0.5176311116042892|
// |@MariaLKanellis Y...|       1.0|0.5132405373445936|
// |says goodmorning ...|       1.0|0.5217622596942644|
// |lovin the rain......|       1.0|0.5217622596942644|
// |Last three days h...|       1.0|0.5083638505529229|
// |@Viki_T oo that d...|       0.0|0.4737966205600386|
// |@ddlovato Nothin ...|       0.0|0.4962577627950444|
// |@Pearlwhite27 hiya! |       1.0|0.5217622596942644|
// +--------------------+----------+------------------+
//
// +--------------------+----------+------------------+
// |               tweet|prediction|   neg_probability|
// +--------------------+----------+------------------+
// |Today is gonna be...|       1.0|0.5259401762003582|
// |@Mr_D Contest is ...|       1.0|0.5217622596942644|
// |shitty, tired, lo...|       1.0|0.5387450342438135|
// |@Nabljudatel @jos...|       0.0|0.4763973438000497|
// |Happy Birthday to...|       1.0|0.5255961051627059|
// |@grooveecar thats...|       1.0|0.5217622596942644|
// |Good morning ever...|       1.0|0.5058195948738373|
// |@JonFolse I have ...|       0.0|0.4920798462889506|
// |Watching Friday 1...|       0.0|0.4917648044431682|
// |Run's House is th...|       1.0|0.5074473069320691|
// +--------------------+----------+------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@dougiemcfly @tom...|       1.0|  0.505926882885284|
// |@heycassadee I wa...|       0.0|0.47607270373679844|
// |@LadyHaunter no, ...|       0.0| 0.4920798462889506|
// |@_hb nice tip abo...|       0.0|0.49920395905146264|
// |My head is not my...|       0.0| 0.4574235853755431|
// |having a bad feel...|       1.0| 0.5064894556300061|
// |@murphster47 ha h...|       1.0| 0.5217622596942644|
// |@Widgetty Ahhh bl...|       1.0| 0.5176311116042892|
// |@loving_my_Dew Th...|       1.0| 0.5217622596942644|
// |@alexshelton &amp...|       0.0|0.48723560074692013|
// |@aneD Hey hey Den...|       1.0| 0.5346138861538383|
// |@squink I need to...|       0.0| 0.4837707816928815|
// |@schaumby hey bro...|       1.0|  0.511625223438163|
// |@_Tweek That's so...|       1.0| 0.5354852838116544|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |@inlovewithsteff ...|       1.0| 0.5007535562424307|
// |time to run some ...|       1.0| 0.5134531950981953|
// |sicky  and my mum...|       1.0| 0.5311504032472203|
// |I love my 2 day w...|       0.0|0.49754676323492086|
// |is not looking fo...|       1.0| 0.5134531950981953|
// |Ay dios mio - Los...|       1.0| 0.5217622596942644|
// |#poopininthenoog ...|       0.0|  0.477622115194505|
// |Alright, had Stra...|       1.0| 0.5248106796415233|
// |@astoldbydes yes....|       1.0| 0.5217622596942644|
// |Feast's day tomor...|       1.0| 0.5217622596942644|
// |John Travolta boo...|       0.0|0.49341905526564045|
// |@andrewdearling h...|       1.0| 0.5217622596942644|
// |@Chaanah79 - yes ...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |mothers day sucks...|       1.0| 0.5094300515232023|
// |Def cant b home f...|       0.0|0.47090663712636494|
// |@NinaChantele Hop...|       0.0|  0.495651777362445|
// |@Palchan Rest its...|       1.0| 0.5217622596942644|
// |SOB! I hate going...|       0.0| 0.4654730959947928|
// |Relaxing...not go...|       1.0| 0.5346279686983664|
// |I'm not feeling h...|       1.0| 0.5210191607616257|
// |@intelligensia I'...|       1.0| 0.5134531950981953|
// |Noooooo! They are...|       0.0| 0.4906558198925297|
// |I'm going to watc...|       1.0|  0.512030045103656|
// |I shall stop twee...|       0.0|  0.477328524891388|
// |@GingerCM @autism...|       0.0| 0.4925441128903264|
// |I've put a new ar...|       1.0| 0.5164395583079437|
// +--------------------+----------+-------------------+
//
// +--------------------+----------+-------------------+
// |               tweet|prediction|    neg_probability|
// +--------------------+----------+-------------------+
// |I need more twitt...|       1.0| 0.5005009031532752|
// |Good Mornin my tw...|       0.0|0.48794869819897546|
// |Im going 2 make O...|       1.0| 0.5000547859568538|
// |@bklyncookie hang...|       1.0| 0.5157563715281381|
// |there own today.....|       0.0|0.48308593911967534|
// |YAY i came back o...|       1.0| 0.5091234717991464|
// |So apparently @j_...|       1.0| 0.5083187045898852|
// |just saw the prev...|       0.0|0.49649648302561655|
// |Only one more wee...|       1.0| 0.5085649024845892|
// |spent the night a...|       1.0| 0.5217622596942644|
// +--------------------+----------+-------------------+

// %%
val predictions_stats = predictionsDF
    .withColumn("timestamp", current_timestamp())
    .withWatermark("timestamp", "10 seconds")
    .groupBy($"prediction", window($"timestamp", "10 seconds", "1 second"))
    .count()
// Out:
// predictions_stats = [prediction: double, window: struct<start: timestamp, end: timestamp> ... 1 more field]
// [prediction: double, window: struct<start: timestamp, end: timestamp> ... 1 more field]

// %%
val console_stream = predictions_stats
    .writeStream
    .outputMode("append")
    .format("console")
    .start()
// Out:
// console_stream = org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@77d9e94
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@77d9e94
// -------------------------------------------
// Batch: 0
// -------------------------------------------
// +----------+------+-----+
// |prediction|window|count|
// +----------+------+-----+
// +----------+------+-----+
//
// -------------------------------------------
// Batch: 1
// -------------------------------------------
// +----------+------+-----+
// |prediction|window|count|
// +----------+------+-----+
// +----------+------+-----+
//
// -------------------------------------------
// Batch: 2
// -------------------------------------------
// +----------+--------------------+-----+
// |prediction|              window|count|
// +----------+--------------------+-----+
// |       1.0|[2019-10-16 12:27...|    4|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|    4|
// |       1.0|[2019-10-16 12:27...|    4|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|    4|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|    4|
// |       1.0|[2019-10-16 12:27...|    4|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|    4|
// |       1.0|[2019-10-16 12:27...|    4|
// |       1.0|[2019-10-16 12:27...|    4|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|    4|
// +----------+--------------------+-----+
//
// -------------------------------------------
// Batch: 3
// -------------------------------------------
// +----------+--------------------+-----+
// |prediction|              window|count|
// +----------+--------------------+-----+
// |       1.0|[2019-10-16 12:27...|   10|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|   10|
// |       1.0|[2019-10-16 12:27...|   10|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|   10|
// |       0.0|[2019-10-16 12:27...|   12|
// +----------+--------------------+-----+
//
// -------------------------------------------
// Batch: 4
// -------------------------------------------
// +----------+--------------------+-----+
// |prediction|              window|count|
// +----------+--------------------+-----+
// |       1.0|[2019-10-16 12:27...|    8|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|   10|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|   10|
// |       1.0|[2019-10-16 12:27...|    8|
// |       0.0|[2019-10-16 12:27...|    5|
// |       1.0|[2019-10-16 12:27...|    8|
// |       1.0|[2019-10-16 12:27...|   10|
// |       0.0|[2019-10-16 12:27...|    5|
// |       1.0|[2019-10-16 12:27...|   10|
// |       1.0|[2019-10-16 12:27...|   10|
// |       1.0|[2019-10-16 12:27...|    8|
// |       0.0|[2019-10-16 12:27...|    5|
// |       1.0|[2019-10-16 12:27...|    8|
// |       0.0|[2019-10-16 12:27...|    5|
// |       0.0|[2019-10-16 12:27...|   12|
// |       0.0|[2019-10-16 12:27...|    5|
// |       0.0|[2019-10-16 12:27...|   12|
// |       1.0|[2019-10-16 12:27...|   10|
// +----------+--------------------+-----+
// only showing top 20 rows
